# %% [markdown]
# # Superflip — Jane Street, August 2014
#
# https://www.janestreet.com/puzzles/superflip-index/
#
# ## Solution: 24794911296
#
# ## AI Use disclaimer
#
# No AI use.
#
#
# ## Conclusion
#
# Fun but fairly straightforward!

# %% [markdown]
# ## Initial thoughts
#
# The 6 different colored 3x3 squares of letters and the name superflip point right to a rubics cube!  Superflip, I learned, is a pattern you can make on a rubics cube, I'm gonna see what happens to the grid if I do a superflip.

# %% [markdown]
# ## Harder than I thought to visualize
#
# OK its way harder than I thought to think through. Without writing software everything gets a bit jumbled.  My best hints is that the white squares seem like they will spell "What is the... then the red will spell "number ..." So lets run with that.  I found this site that let me do a superflip and look at a flat grid too: https://onlinecube.com/.  I think the key is that we only swap edges at positions 2, 4, 6, and 8 of each square, and white and yellow are opposite so white takes one edge from Red, Blue, Orange and Green.  Each face gets one edge from every color except its opposite.  With the strong suspicion of the initial clue words, I think that'll be enough.

# %% [markdown]
# Got it -- the final answer is "What is the number of stickers on a rubiks cube cubed then squared."
#
# A rubics cube has 9 stickers per side, so the answer is $((9*6)^3)^2 = 54^6$

# %%
print(54**6)
# Out:
# 24794911296
