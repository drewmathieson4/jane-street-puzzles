# %% [markdown]
# # Block Party 4
#
# **Jane Street puzzle, June 2022** — [puzzle page](https://www.janestreet.com/puzzles/block-party-4-index/)

# %% [markdown]
# > **AI use:** This notebook was scaffolded by an AI assistant — the title, link, and puzzle description below were pulled from the Jane Street archive automatically. Everything from the Solution heading down is my own work unless a cell says otherwise.

# %% [markdown]
# ## Puzzle
#
# ![Puzzle image](https://www.janestreet.com/puzzles/block-party-4.png)
#
# Fill each region with the numbers 1 through _N_, where _N_ is the number of cells in the region. For each number _K_ in the grid, the nearest _K_ **via taxicab distance** must be exactly _K_ cells away.
#
# Once the grid is completed, the answer to the puzzle is found as follows: compute the product of the values in each row, and then take the sum of these products.

# %% [markdown]
# ## Solution
#
# _Not started yet._
