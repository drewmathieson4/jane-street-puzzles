# %% [markdown]
# # Star Search
#
# **Jane Street puzzle, December 2016** — [puzzle page](https://www.janestreet.com/puzzles/star-search-index/)

# %% [markdown]
# > **AI use:** This notebook was scaffolded by an AI assistant — the title, link, and puzzle description below were pulled from the Jane Street archive automatically. Everything from the Solution heading down is my own work unless a cell says otherwise.

# %% [markdown]
# ## Puzzle
#
# ![Star Search Puzzle Image](https://www.janestreet.com/puzzles/Dec16_Puzzle_revised.png)
#
# **The answer to this month's puzzle is a movie.**
#
# _See the puzzle page for the full statement._

# %% [markdown]
# ## Solution
#
# _Not started yet._
