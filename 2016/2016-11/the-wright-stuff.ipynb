# %% [markdown]
# # The Wright Stuff
#
# **Jane Street puzzle, November 2016** — [puzzle page](https://www.janestreet.com/puzzles/the-wright-stuff-index/)

# %% [markdown]
# > **AI use:** This notebook was scaffolded by an AI assistant — the title, link, and puzzle description below were pulled from the Jane Street archive automatically. Everything from the Solution heading down is my own work unless a cell says otherwise.

# %% [markdown]
# ## Puzzle
#
# ![](https://www.janestreet.com/puzzles/nov16_puzzle.png)
#
# _(The answer to this puzzle, which comprises 11 letters, is on the National Register of Historic Places.)_
#
# _See the puzzle page for the full statement._

# %% [markdown]
# ## Solution
#
# _Not started yet._
