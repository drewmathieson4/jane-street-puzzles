# %% [markdown]
# # Game Night!
#
# **Jane Street puzzle, May 2023** — [puzzle page](https://www.janestreet.com/puzzles/game-night-index/)

# %% [markdown]
# > **AI use:** This notebook was scaffolded by an AI assistant — the title, link, and puzzle description below were pulled from the Jane Street archive automatically. Everything from the Solution heading down is my own work unless a cell says otherwise.

# %% [markdown]
# ## Puzzle
#
# ![https://www.janestreet.com/puzzles/game-night.png](https://www.janestreet.com/puzzles/game-night.png)
#
# "The three best first plays from our recurring [Codenames](https://boardgamegeek.com/boardgame/178900/codenames) game night are pictured above: one matched eleven words and the other two matched nine each!"
#
# "We looked at the boards over and over again and decided that when the clues encode the target words in such a binary fashion you can get impressive results."
#
# _[The answer to this puzzle is a single word.]_

# %% [markdown]
# ## Solution
#
# _Not started yet._
