# %% [markdown]
# # Hall of Mirrors 2
#
# **Jane Street puzzle, December 2023** — [puzzle page](https://www.janestreet.com/puzzles/hall-of-mirrors-2-index/)

# %% [markdown]
# > **AI use:** This notebook was scaffolded by an AI assistant — the title, link, and puzzle description below were pulled from the Jane Street archive automatically. Everything from the Solution heading down is my own work unless a cell says otherwise.

# %% [markdown]
# ## Puzzle
#
# ![https://www.janestreet.com/puzzles/20231201_mirrors_2.PNG](https://www.janestreet.com/puzzles/20231201_mirrors_2.PNG)
#
# _See the puzzle page for the full statement._

# %% [markdown]
# ## Solution
#
# _Not started yet._
