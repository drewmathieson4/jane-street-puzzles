# %% [markdown]
# # Tit for Tat
#
# **Jane Street puzzle, March 2021** — [puzzle page](https://www.janestreet.com/puzzles/tit-for-tat-index/)

# %% [markdown]
# > **AI use:** This notebook was scaffolded by an AI assistant — the title, link, and puzzle description below were pulled from the Jane Street archive automatically. Everything from the Solution heading down is my own work unless a cell says otherwise.

# %% [markdown]
# ## Puzzle
#
# The answer is a two-word English phrase.
#
# - Drivers destabilise? (6.4)
# - Help a top-roper with your gut? (5.4)
# - Weak point of a lever? (5.4)
# - Reorganises puffy desserts? (8.2)
# - What you need to get the flattest dough? (5.1)
# - Numerically, the body of water coming after the one at Edinburgh? (5.3)
# - 2-for-1 on name-brand soap? (4.2)
# - Nirvana feud? (6.4)
# - (6.1)

# %% [markdown]
# ## Solution
#
# _Not started yet._
