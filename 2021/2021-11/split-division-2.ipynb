# %% [markdown]
# # Split Division 2
#
# **Jane Street puzzle, November 2021** — [puzzle page](https://www.janestreet.com/puzzles/split-division-2-index/)

# %% [markdown]
# > **AI use:** This notebook was scaffolded by an AI assistant — the title, link, and puzzle description below were pulled from the Jane Street archive automatically. Everything from the Solution heading down is my own work unless a cell says otherwise.

# %% [markdown]
# ## Puzzle
#
# ![Split Division 2 grid](https://www.janestreet.com/puzzles/2021-11-01-split-division-2.png)
#
# Two long division problems were calculated, and both problems had the exact same shape. At some places, the digits from the two problems were both positive and had a greatest common divisor that was larger than 1. **All** of those spots are marked with their respective GCDs.
#
# The answer to this puzzle is the **sum** of the two 7-digit dividends in the completed long division problems.

# %% [markdown]
# ## Solution
#
# _Not started yet._
