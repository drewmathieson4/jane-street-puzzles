# %% [markdown]
# # Birthday Bash
#
# **Jane Street puzzle, March 2017** — [puzzle page](https://www.janestreet.com/puzzles/birthday-bash-index/)

# %% [markdown]
# > **AI use:** This notebook was scaffolded by an AI assistant — the title, link, and puzzle description below were pulled from the Jane Street archive automatically. Everything from the Solution heading down is my own work unless a cell says otherwise.

# %% [markdown]
# ## Puzzle
#
# What is the minimum size of a randomly selected group of people such that there is a greater than 50% chance they can celebrate the birthday of at least one person in the group on every day of the year? Assume that all years have 365 days, and that birthdays are evenly spread throughout the year.

# %% [markdown]
# ## Solution
#
# _Not started yet._
