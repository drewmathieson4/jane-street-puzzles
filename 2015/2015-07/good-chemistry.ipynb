# %% [markdown]
# # Good Chemistry
#
# **Jane Street puzzle, July 2015** — [puzzle page](https://www.janestreet.com/puzzles/good-chemistry-index/)

# %% [markdown]
# > **AI use:** This notebook was scaffolded by an AI assistant — the title, link, and puzzle description below were pulled from the Jane Street archive automatically. Everything from the Solution heading down is my own work unless a cell says otherwise.

# %% [markdown]
# ## Puzzle
#
# **V-E+F=2**
#
# f(ethanol) = 6
#
# f(paracetamol) = 242
#
# f(caffeine) = 630
#
# f(acetone) = 12
#
# f(uracil) = 128
#
# f(naphthalene) = 330
#
# f(nitroglycerin) = 210
#
# f(adenosine triphosphate) = ?

# %% [markdown]
# ## Solution
#
# _Not started yet._
