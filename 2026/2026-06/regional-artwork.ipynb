# %% [markdown]
# # Regional Artwork
#
# **Jane Street puzzle, June 2026** — [puzzle page](https://www.janestreet.com/puzzles/regional-artwork-index/)
#
# **Solution:** "American Grafitti"

# %% [markdown]
# ## Puzzle
#
# ![Regional Artwork](https://www.janestreet.com/puzzles/regional-artwork.jpg)
#
# 1. frequent Frazier foe
# 2. type of magazine you might start getting in your 20's
# 3. arguably, the story of our time (and a hint to answering all the _other_ clues…)
# 4. stage name of a famous skeptic (with "The")
# 5. Oscar-winning role from the 80's
# 6. often-inset pair, for short
# 7. microwaveable snack brand that replaced a refrigerated product
# 8. where to find "take thou this vial" and "double, double toil and trouble"
# 9. you might break it in Kabul
# 10. eponym of multiple continents (and the answer that should come last after sorting)
# 11. onetime Outkast output
# 12. notable 2026 launch
# 13. the present, in the past
# 14. our nearest neighbors, in some sense (though we haven't visited yet…)
#
# **The answers to these clues need sorting!** Move them into their proper locations, then use those moves to populate the final clue, below.
#
# `__ __ __ __ __ __  __ __ __ __ __  __ __ __`
# `7 8 10 15 12 9  13 6 11 3 14  4 2 5`

# %% [markdown]
# ## Initial clues
#
# We have a series of crossword style clues, that I'm going to solve.  Immediately I notice that they all start with A and end in I, as indicated by the third clue.  Google helps answer them all.

# %%
1. frequent Frazier foe -- ALI
2. type of magazine you might start getting in your 20's -- ALUMNI
3. arguably, the story of our time (and a hint to answering all the _other_ clues…) -- AI
4. stage name of a famous skeptic (with "The") -- AMAZING RANDI
5. Oscar-winning role from the 80's -- ANTONIO SALIERI
6. often-inset pair, for short -- AKHI
7. microwaveable snack brand that replaced a refrigerated product -- ACT II
8. where to find "take thou this vial" and "double, double toil and trouble" - ACT IV, SCENE I
9. you might break it in Kabul -- AFGHANI
10. eponym of multiple continents (and the answer that should come last after sorting) -- AMERIGO VESPUCCI 
11. onetime Outkast output -- AQUEMINI
12. notable 2026 launch -- ARTEMISII
13. the present, in the past -- ANNO DOMINI
14. our nearest neighbors, in some sense (though we haven't visited yet…) -- ALPHA CENTAURI

# %% [markdown]
# ## Sorting
#
# We know that we need to sort the clues, and that AMERIGO VESPUCCI needs to be last.  Since that's the longest clue, we can look at length.
#
# If we remove spaces, then each clue solves to a unique length, perfectly represented in the answer text.
#
# The new ordering is...
#
# | Original | Final | Clue | Answer | Length |
# |---|---|---|---|---|
# | 3 | 1 | arguably, the story of our time (and a hint to answering all the _other_ clues…) | AI | 2 |
# | 1 | 2 | frequent Frazier foe | ALI | 3 |
# | 6 | 3 | often-inset pair, for short | AKHI | 4 |
# | 7 | 4 | microwaveable snack brand that replaced a refrigerated product | ACTII | 5 |
# | 2 | 5 | type of magazine you might start getting in your 20's | ALUMNI | 6 |
# | 9 | 6 | you might break it in Kabul | AFGHANI | 7 |
# | 11 | 7 | onetime Outkast output | AQUEMINI | 8 |
# | 12 | 8 | notable 2026 launch | ARTEMISII | 9 |
# | 13 | 9 | the present, in the past | ANNODOMINI | 10 |
# | 8 | 10 | where to find "take thou this vial" and "double, double toil and trouble" | ACTIVSCENEI | 11 |
# | 4 | 11 | stage name of a famous skeptic (with "The") | AMAZINGRANDI | 12 |
# | 14 | 12 | our nearest neighbors, in some sense (though we haven't visited yet…) | ALPHACENTAURI | 13 |
# | 5 | 13 | Oscar-winning role from the 80's | ANTONIOSALIERI | 14 |
# | 10 | 14 | eponym of multiple continents (and the answer that should come last after sorting) | AMERIGOVESPUCCI | 15 |

# %% [markdown]
# FUNP
# NII

# %% [markdown]
# The last thing we need to do is extract a letter from each clue.  We still haven't used the title of the puzzle, regional artwork, so thats a good place to start.  I think that the idea would be that we need to "draw" the changes in position potentially?
#
# The setup reminds me of the tower of hanoi puzzle.
#
# Original:
#
# ```
# ALI
# ALUMNI
# AI
# AMAZINGRANDI
# ANTONIOSALIERI
# AKHI
# ACTII
# ACTIVSCENEI
# AFGHANI
# AMERIGOVESPUCCI
# AQUEMINI
# ARTEMISII
# ANNODOMINI
# ALPHACENTAURI
# ```
#
# Final:
#
# ```
# AI
# ALI
# AKHI
# ACTII
# ALUMNI
# AFGHANI
# AQUEMINI
# ARTEMISII
# ANNODOMINI
# ACTIVSCENEI
# AMAZINGRANDI
# ALPHACENTAURI
# ANTONIOSALIERI
# AMERIGOVESPUCCI
# ```

# %% [markdown]
# ## Index into answer by original location?
#
# OK, so for the number 7, we go to the answer with length 7, which is AFGHANI.  That word moved 3 spots, so we index to `G`.
#
# Continuing with that pattern, we get...
#
# 'George Lucas Hit'.
#
# A quick google search gives 'American Grafitti', a fitting answer to this puzzle.
