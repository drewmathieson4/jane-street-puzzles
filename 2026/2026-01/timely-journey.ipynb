# %% [markdown]
# # Timely Journey
#
# **Jane Street puzzle, January 2026** — [puzzle page](https://www.janestreet.com/puzzles/timely-journey-index/)

# %% [markdown]
# > **AI use:** This notebook was scaffolded by an AI assistant — the title, link, and puzzle description below were pulled from the Jane Street archive automatically. Everything from the Solution heading down is my own work unless a cell says otherwise.

# %% [markdown]
# ## Puzzle
#
# ![Timely Journey](https://www.janestreet.com/puzzles/timely-journey.jpg)
#
# (A copy of the paper shown above can be seen [here](https://www.janestreet.com/static/pdfs/puzzles/jan-2026-timely-journey.pdf).)
#
# _Good luck._
#
# _See the puzzle page for the full statement._

# %% [markdown]
# ## Solution
#
# _Not started yet._
