# %% [markdown]
# # Single-Cross
#
# **Jane Street puzzle, February 2020** — [puzzle page](https://www.janestreet.com/puzzles/single-cross-index/)

# %% [markdown]
# > **AI use:** This notebook was scaffolded by an AI assistant — the title, link, and puzzle description below were pulled from the Jane Street archive automatically. Everything from the Solution heading down is my own work unless a cell says otherwise.

# %% [markdown]
# ## Puzzle
#
# A random line segment of length D is chosen on a plane marked with an infinite checkerboard grid (i.e., a unit side length square grid). What length D maximizes the probability that the segment crosses exactly one line on the checkerboard grid, and what is this maximal probability?

# %% [markdown]
# ## Solution
#
# _Not started yet._
