# %% [markdown]
# # Some Ones, Somewhere
#
# **Jane Street puzzle, June 2025** — [puzzle page](https://www.janestreet.com/puzzles/some-ones-somewhere-index/)

# %% [markdown]
# > **AI use:** This notebook was scaffolded by an AI assistant — the title, link, and puzzle description below were pulled from the Jane Street archive automatically. Everything from the Solution heading down is my own work unless a cell says otherwise.

# %% [markdown]
# ## Puzzle
#
# _(The answer to this month's puzzle is a sentence.)_
#
# The full puzzle statement is published as a PDF: [june-2025-puzzle.pdf](https://www.janestreet.com/static/pdfs/puzzles/june-2025-puzzle.pdf).
#
# _See the puzzle page for the full statement._

# %% [markdown]
# ## Solution
#
# _Not started yet._
