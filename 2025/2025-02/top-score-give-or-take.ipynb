# %% [markdown]
# # Top Score (Give or Take)
#
# **Jane Street puzzle, February 2025** — [puzzle page](https://www.janestreet.com/puzzles/top-score-give-or-take-index/)

# %% [markdown]
# > **AI use:** This notebook was scaffolded by an AI assistant — the title, link, and puzzle description below were pulled from the Jane Street archive automatically. Everything from the Solution heading down is my own work unless a cell says otherwise.

# %% [markdown]
# ## Puzzle
#
# ![](https://www.janestreet.com/puzzles/top-score-give-or-take.jpg)
#
# _[The answer to this puzzle is a proper noun.]_
#
# _See the puzzle page for the full statement._

# %% [markdown]
# ## Solution
#
# _Not started yet._
